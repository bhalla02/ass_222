# %% [markdown]
# Q1
# Linear Regression:
#
# Purpose: Used for predicting a continuous dependent variable based on one or more independent variables.
# Output: Continuous values.
# Equation:
# 𝑦
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑥
# 1
# +
# 𝛽
# 2
# 𝑥
# 2
# +
# ⋯
# +
# 𝛽
# 𝑛
# 𝑥
# 𝑛
# y=β
# 0
# ​
#  +β
# 1
# ​
#  x
# 1
# ​
#  +β
# 2
# ​
#  x
# 2
# ​
#  +⋯+β
# n
# ​
#  x
# n
# ​
#
# Example Scenario: Predicting house prices based on features like size, number of bedrooms, location, etc.
#
#
# Logistic Regression:
#
# Purpose: Used for predicting a binary dependent variable (0 or 1) based on one or more independent variables.
# Output: Probabilities that are then mapped to class labels (0 or 1).
# Equation:
# 𝑃
# (
# 𝑌
# =
# 1
# )
# =
# 1
# 1
# +
# 𝑒
# −
# (
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑥
# 1
# +
# 𝛽
# 2
# 𝑥
# 2
# +
# ⋯
# +
# 𝛽
# 𝑛
# 𝑥
# 𝑛
# )
# P(Y=1)=
# 1+e
# −(β
# 0
# ​
#  +β
# 1
# ​
#  x
# 1
# ​
#  +β
# 2
# ​
#  x
# 2
# ​
#  +⋯+β
# n
# ​
#  x
# n
# ​
#  )
#
# 1
# ​
#
# Example Scenario: Predicting whether a customer will buy a product (1) or not (0) based on their demographic and behavioral data.

# %% [markdown]
# Q2
# Cost Function: Logistic regression uses the logistic loss or cross-entropy loss as the cost function.
# Formula:
# 𝐽
# (
# 𝜃
# )
# =
# −
# 1
# 𝑚
# ∑
# 𝑖
# =
# 1
# 𝑚
# [
# 𝑦
# (
# 𝑖
# )
# log
# ⁡
# (
# ℎ
# 𝜃
# (
# 𝑥
# (
# 𝑖
# )
# )
# )
# +
# (
# 1
# −
# 𝑦
# (
# 𝑖
# )
# )
# log
# ⁡
# (
# 1
# −
# ℎ
# 𝜃
# (
# 𝑥
# (
# 𝑖
# )
# )
# )
# ]
# J(θ)=−
# m
# 1
# ​
#  ∑
# i=1
# m
# ​
#  [y
# (i)
#  log(h
# θ
# ​
#  (x
# (i)
#  ))+(1−y
# (i)
#  )log(1−h
# θ
# ​
#  (x
# (i)
#  ))]
# Optimization: This cost function is optimized using gradient descent or more advanced optimization algorithms like L-BFGS or stochastic gradient descent (SGD).

# %% [markdown]
# Q3
